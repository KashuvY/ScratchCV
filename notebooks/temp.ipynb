# %%
import importlib
import cv_lib.core.image
importlib.reload(cv_lib.core.image)
# Out:
# <module 'cv_lib.core.image' from 'c:\\users\\youva\\college\\repos\\scratchcv\\cv_lib\\core\\image.py'>

# %%
from cv_lib.core.image import Image
import matplotlib.pyplot as plt
import numpy as np

# Test with a small numpy array first
img = Image("../img/panda.jpg")
img = img.to_grayscale()
img.show()
resized = img.resize(517, 300)
resized.show()
# Out:
# Loading image from ../img/panda.jpg
# Initial load shape: (427, 640, 3), dtype: uint8
# Final data shape: (427, 640, 3), dtype: float32
# is_grayscale check: shape=(427, 640, 3), result=False
# Array input shape: (427, 640, 1), dtype: float64
# Final data shape: (427, 640, 1), dtype: float64
# is_grayscale check: shape=(427, 640, 1), result=True
# Array input shape: (517, 300, 1), dtype: float64
# Final data shape: (517, 300, 1), dtype: float64
# is_grayscale check: shape=(517, 300, 1), result=True
